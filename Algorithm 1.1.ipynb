# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib.animation as anima
import random
import networkx
import math as ma
import pandas as pd
from math import pi
from scipy.spatial import voronoi_plot_2d, Voronoi
from scipy.stats import*
import scipy.stats as stats
from sklearn import datasets
from qiskit import*
from qiskit.visualization import*

# %%
plt.figure(figsize=(20,20))
plt.xlim(0,1)


N= 500
x = []
y = []
pontos_gerados = []
for i in range(N):
    x_ = random.random() # gera uma coordenada x aleatória 
    y_ =random.random()  # gera uma coordenada y aleatória  
    x.append(x_) # Adiciona na lista x 
    y.append(y_) # Adiciona na lista y

x__ = random.sample(x,N) # Agrupa os pontos em samples
y__ = random.sample(y,N) # Agrupa os pontos em samples
for i in range(N):
    pontos_gerados.append([x__[i],y__[i]]) # gera lista com pontos no formato (x,y)
    


    
plt.plot(x__,y__,'yo')


xc_1 =random.random()# gera uma coordenada x para o centroide 1 aleatória
yc_1=random.random() # gera uma coordenada y para o centróide 1 aleatória
plt.plot(xc_1,yc_1,'ro') # plota o centróide (xc_1,yc_1) no gráfico



#-------------------------------------------------------------------
xc_2 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_2=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_2,yc_2,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------

xc_3 =random.random()# gera uma coordenada x para o centroide 1 aleatória
yc_3=random.random() # gera uma coordenada y para o centróide 1 aleatória
plt.plot(xc_3,yc_3,'ro') # plota o centróide (xc_1,yc_1) no gráfico



#-------------------------------------------------------------------
xc_4 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_4=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_4,yc_4,'ro') # plota o centróide (xc_2,yc_2) no gráfico

    
#-------------------------------------------------------------------

xc_5=random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_5=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_5,yc_5,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_6=random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_6=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_6,yc_6,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_7 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_7=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_7,yc_7,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_8 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_8=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_8,yc_8,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_9 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_9=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_9,yc_9,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_10 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_10=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_10,yc_10,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_11 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_11=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_11,yc_11,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_12 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_12=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_12,yc_12,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_13 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_13=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_13,yc_13,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_14 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_14=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_14,yc_14,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_15 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_15=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_15,yc_15,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_16 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_16=random.random() # gera uma coordenada y para o centróide 2 aleatória
plt.plot(xc_16,yc_16,'ro') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------

        



xc_1_ = []
xc_1_.append(xc_1)

# %%
#-------------------------------------------------------------------------------------------------------------------------------------------------
pontos1_= []
pontos2_ = []
pontos3_ = []
pontos4_= []
pontos5_= []
pontos6_ = []
pontos7_ = []
pontos8_= []
pontos9_= []
pontos10_ = []
pontos11_ = []
pontos12_= []
pontos13_= []
pontos14_ = []
pontos15_ = []
pontos16_= []




plt.figure(figsize=(20,20))
plt.grid()

dist1 = [] # lista das distancias do centroide 1 aos pontos do dataset
dist2 = [] # lista das distancias do centroide 2 aos pontos do dataset
dist3 = [] # lista das distancias do centroide 3 aos pontos do dataset
dist4 = [] # lista das distancias do centroide 4 aos pontos do dataset
dist5 = [] # lista das distancias do centroide 5 aos pontos do dataset
dist6 = [] # lista das distancias do centroide 6 aos pontos do dataset
dist7 = [] # lista das distancias do centroide 6 aos pontos do dataset
dist8 = [] # lista das distancias do centroide 6 aos pontos do dataset
dist9 = [] # lista das distancias do centroide 6 aos pontos do dataset
dist10 = [] # lista das distancias do centroide 6 aos pontos do dataset
dist11 = [] # lista das distancias do centroide 6 aos pontos do dataset
dist12 = [] # lista das distancias do centroide 6 aos pontos do dataset
dist13 = [] # lista das distancias do centroide 6 aos pontos do dataset
dist14 = [] # lista das distancias do centroide 6 aos pontos do dataset
dist15= [] # lista das distancias do centroide 6 aos pontos do dataset
dist16 = [] # lista das distancias do centroide 6 aos pontos do dataset


for i in range(len(pontos_gerados)):
    dist_1 = ((x[i] - xc_1)**2 + (y[i]-yc_1)**2)**(1/2)
    dist_2 = ((x[i] - xc_2)**2 + (y[i] - yc_2)**2)**(1/2)
    dist_3= ((x[i] - xc_3)**2 + (y[i] - yc_3)**2)**(1/2)
    dist_4 = ((x[i] - xc_4)**2 + (y[i] - yc_4)**2)**(1/2)
    dist_5 = ((x[i] - xc_5)**2 + (y[i] - yc_5)**2)**(1/2)
    dist_6 = ((x[i] - xc_6)**2 + (y[i] - yc_6)**2)**(1/2)
    dist_7 = ((x[i] - xc_7)**2 + (y[i] - yc_7)**2)**(1/2)
    dist_8 = ((x[i] - xc_8)**2 + (y[i] - yc_8)**2)**(1/2)
    dist_9 = ((x[i] - xc_9)**2 + (y[i] - yc_9)**2)**(1/2)
    dist_10 = ((x[i] - xc_10)**2 + (y[i] - yc_10)**2)**(1/2)
    dist_11 = ((x[i] - xc_11)**2 + (y[i] - yc_11)**2)**(1/2)
    dist_12 = ((x[i] - xc_12)**2 + (y[i] - yc_12)**2)**(1/2)
    dist_13 = ((x[i] - xc_13)**2 + (y[i] - yc_13)**2)**(1/2)
    dist_14 = ((x[i] - xc_14)**2 + (y[i] - yc_14)**2)**(1/2)
    dist_15 = ((x[i] - xc_15)**2 + (y[i] - yc_15)**2)**(1/2)
    dist_16 = ((x[i] - xc_16)**2 + (y[i] - yc_16)**2)**(1/2)
    
    
    
    dist1.append(dist_1)
    dist2.append(dist_2)
    dist3.append(dist_3)
    dist4.append(dist_4)
    dist5.append(dist_5)
    dist6.append(dist_6)
    dist7.append(dist_7)
    dist8.append(dist_8)
    dist9.append(dist_9)
    dist10.append(dist_10)
    dist11.append(dist_11)
    dist12.append(dist_12)
    dist13.append(dist_13)
    dist14.append(dist_14)
    dist15.append(dist_15)
    dist16.append(dist_16)
    
    
    soma1 = [0,0]
    soma2 = [0,0]
    soma3 = [0,0]
    soma4 = [0,0]
    soma5 = [0,0]
    soma6 = [0,0]
    soma7 = [0,0]
    soma8 = [0,0]
    soma9 = [0,0]
    soma10 = [0,0]
    soma11 = [0,0]
    soma12 = [0,0]
    soma13 = [0,0]
    soma14 = [0,0]
    soma15 = [0,0]
    soma16 = [0,0]
    
    count1 = 1
    count2 = 1
    count3 = 1
    count4 = 1
    count5 = 1
    count6 = 1
    count7 = 1
    count8 = 1
    count9 = 1
    count10 = 1
    count11 = 1
    count12 = 1
    count13 = 1
    count14 = 1
    count15= 1
    count16 = 1
    
    count1_ = []
    count2_ = []
    count3_ = []
    count4_ = []
    count5_ = []
    count6_ = []
    count7_ = []
    count8_ = []
    count9_ = []
    count10_ = []
    count11_ = []
    count12_ = []
    count13_ = []
    count14_ = []
    count15_ = []
    count16_ = []

for i in range(N):
    
    if(dist1[i]<dist2[i] and dist1[i]<dist3[i] and dist1[i]<dist4[i]and dist1[i]<dist5[i] and dist1[i]<dist6[i]and dist1[i]<dist7[i]and dist1[i]<dist8[i]and dist1[i]<dist9[i]and dist1[i]<dist10[i]and dist1[i]<dist11[i]and dist1[i]<dist12[i]and dist1[i]<dist13[i]and dist1[i]<dist14[i]and dist1[i]<dist15[i]and dist1[i]<dist16[i]):
        
        
        
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
    
        
        soma1[0] = soma1[0] + x[i]
        soma1[1] = soma1[1] + y[i]
        count1 = count1 + 1
        count1_.append(count1)
        pontos1_.append([x[i],y[i]])
    elif(dist2[i]<dist1[i] and dist2[i]<dist3[i] and dist2[i]<dist4[i]and dist2[i]<dist5[i] and dist2[i]<dist6[i]and dist2[i]<dist7[i]and dist2[i]<dist8[i]and dist2[i]<dist9[i]and dist2[i]<dist10[i]and dist2[i]<dist11[i]and dist2[i]<dist12[i]and dist2[i]<dist13[i]and dist2[i]<dist14[i]and dist2[i]<dist15[i]and dist2[i]<dist16[i]):
        
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro') 
        soma2[0] = soma2[0] + x[i]
        soma2[1] = soma2[1] + y[i]
      

        count2 = count2 + 1
        count2_.append(count2)
        pontos2_.append([x[i],y[i]])
    elif(dist3[i]<dist1[i] and dist3[i]<dist2[i] and dist3[i]<dist4[i]and dist3[i]<dist5[i] and dist3[i]<dist6[i]and dist3[i]<dist7[i]and dist3[i]<dist8[i]and dist3[i]<dist9[i]and dist3[i]<dist10[i]and dist3[i]<dist11[i]and dist3[i]<dist12[i]and dist3[i]<dist13[i]and dist3[i]<dist14[i]and dist3[i]<dist15[i]and dist3[i]<dist16[i]):
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
        soma3[0] = soma3[0] + x[i]
        soma3[1] = soma3[1] + y[i]

        count3 = count3 + 1
        count3_.append(count3)
        pontos3_.append([x[i],y[i]])
    elif(dist4[i]<dist1[i] and dist4[i]<dist2[i] and dist4[i]<dist3[i]and dist4[i]<dist5[i] and dist4[i]<dist6[i]and dist4[i]<dist7[i]and dist4[i]<dist8[i]and dist4[i]<dist9[i]and dist4[i]<dist10[i]and dist4[i]<dist11[i]and dist4[i]<dist12[i]and dist4[i]<dist13[i]and dist4[i]<dist14[i]and dist4[i]<dist15[i]and dist4[i]<dist16[i]):
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
         
        soma4[0] = soma4[0] + x[i]
        soma4[1] = soma4[1] + y[i]
        
        count4 = count4 + 1
        count4_.append(count4)
        pontos4_.append([x[i],y[i]])
    elif(dist5[i]<dist1[i] and dist5[i]<dist2[i] and dist5[i]<dist3[i]and dist5[i]<dist4[i] and dist5[i]<dist6[i]and dist5[i]<dist7[i]and dist5[i]<dist8[i]and dist5[i]<dist9[i]and dist5[i]<dist10[i]and dist5[i]<dist11[i]and dist5[i]<dist12[i]and dist5[i]<dist13[i]and dist5[i]<dist14[i]and dist5[i]<dist15[i]and dist5[i]<dist16[i]):
        
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
         
        soma5[0] = soma5[0] + x[i]
        soma5[1] = soma5[1] + y[i]
        
        count5 = count5 + 1
        count5_.append(count5)
        pontos5_.append([x[i],y[i]])
    elif(dist6[i]<dist1[i] and dist6[i]<dist2[i] and dist6[i]<dist3[i]and dist6[i]<dist4[i]and dist6[i]<dist5[i] and dist6[i]<dist7[i]and dist6[i]<dist8[i]and dist6[i]<dist9[i]and dist6[i]<dist10[i]and dist6[i]<dist11[i]and dist6[i]<dist12[i]and dist6[i]<dist13[i]and dist6[i]<dist14[i]and dist6[i]<dist15[i]and dist6[i]<dist16[i]):
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
         
        soma6[0] = soma6[0] + x[i]
        soma6[1] = soma6[1] + y[i]
        
        count6 = count6 + 1
        count6_.append(count6)
        pontos6_.append([x[i],y[i]])
    elif(dist7[i]<dist1[i] and dist7[i]<dist2[i] and dist7[i]<dist3[i]and dist7[i]<dist4[i]and dist7[i]<dist5[i] and  dist7[i]<dist6[i]and dist7[i]<dist8[i]and dist7[i]<dist9[i]and dist7[i]<dist10[i]and dist7[i]<dist11[i]and dist7[i]<dist12[i]and dist7[i]<dist13[i]and dist7[i]<dist14[i]and dist7[i]<dist15[i]and dist7[i]<dist16[i]):     
        
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
         
        soma7[0] = soma7[0] + x[i]
        soma7[1] = soma7[1] + y[i]
        
        count7 = count7 + 1
        count7_.append(count7)
        pontos7_.append([x[i],y[i]])
    elif(dist8[i]<dist1[i] and dist8[i]<dist2[i] and dist8[i]<dist3[i] and dist8[i]<dist4[i]and dist8[i]<dist5[i] and dist8[i]<dist6[i]and dist8[i]<dist7[i]and dist8[i]<dist9[i]and dist8[i]<dist10[i]and dist8[i]<dist11[i]and dist8[i]<dist12[i]and dist8[i]<dist13[i]and dist8[i]<dist14[i]and dist8[i]<dist15[i]and dist8[i]<dist16[i]):
    
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
         
        soma8[0] = soma8[0] + x[i]
        soma8[1] = soma8[1] + y[i]
        
        count8 = count8 + 1
        count8_.append(count8)
         
        pontos8_.append([x[i],y[i]])
         
    elif(dist9[i]<dist1[i] and dist9[i]<dist2[i] and dist9[i]<dist3[i] and dist9[i]<dist4[i]and dist9[i]<dist5[i] and dist9[i]<dist6[i]and dist9[i]<dist7[i]and dist9[i]<dist8[i]and dist9[i]<dist10[i]and dist9[i]<dist11[i]and dist9[i]<dist12[i]and dist9[i]<dist13[i]and dist9[i]<dist14[i]and dist9[i]<dist15[i]and dist9[i]<dist16[i]):
    
         
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
         
        soma9[0] = soma9[0] + x[i]
        soma9[1] = soma9[1] + y[i]
        
        count9 = count9 + 1
        count9_.append(count9)
        pontos9_.append([x[i],y[i]])
    
    elif(dist10[i]<dist1[i] and dist10[i]<dist2[i] and dist10[i]<dist3[i] and dist10[i]<dist4[i]and dist10[i]<dist5[i] and dist10[i]<dist6[i]and dist10[i]<dist7[i]and dist10[i]<dist8[i] and dist10[i]<dist9[i]and dist10[i]<dist11[i]and dist10[i]<dist12[i]and dist10[i]<dist13[i]and dist10[i]<dist14[i]and dist10[i]<dist15[i]and dist10[i]<dist16[i]):
    
         
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
         
        soma10[0] = soma10[0] + x[i]
        soma10[1] = soma10[1] + y[i]
        
        count10 = count10 + 1
        count10_.append(count10)
        pontos10_.append([x[i],y[i]])
    
    elif(dist11[i]<dist1[i] and dist11[i]<dist2[i] and dist11[i]<dist3[i] and dist11[i]<dist4[i]and dist11[i]<dist5[i] and dist11[i]<dist6[i]and dist11[i]<dist7[i]and dist11[i]<dist8[i]and dist11[i]<dist9[i]and dist11[i]<dist10[i] and dist11[i]<dist12[i]and dist11[i]<dist13[i]and dist11[i]<dist14[i]and dist11[i]<dist15[i]and dist11[i]<dist16[i]):
        
        
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
         
        soma11[0] = soma11[0] + x[i]
        soma11[1] = soma11[1] + y[i]
        
        count11 = count11 + 1
        count11_.append(count11) 
        pontos11_.append([x[i],y[i]])
    elif(dist12[i]<dist1[i] and dist12[i]<dist2[i] and dist12[i]<dist3[i] and dist12[i]<dist4[i]and dist12[i]<dist5[i] and dist12[i]<dist6[i]and dist12[i]<dist7[i]and dist12[i]<dist8[i]and dist12[i]<dist9[i]and dist12[i]<dist10[i] and dist12[i]<dist11[i]and dist12[i]<dist13[i]and dist12[i]<dist14[i]and dist12[i]<dist15[i]and dist12[i]<dist16[i]):
        
        
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
         
        soma12[0] = soma12[0] + x[i]
        soma12[1] = soma12[1] + y[i]
        
        count12 = count12 + 1
        count12_.append(count12) 
        pontos12_.append([x[i],y[i]])
         
    elif(dist13[i]<dist1[i] and dist13[i]<dist2[i] and dist13[i]<dist3[i] and dist13[i]<dist4[i]and dist13[i]<dist5[i] and dist13[i]<dist6[i]and dist13[i]<dist7[i]and dist13[i]<dist8[i]and dist13[i]<dist9[i]and  dist13[i]<dist10[i] and dist13[i]<dist11[i]and dist13[i]<dist12[i]and dist13[i]<dist14[i]and dist13[i]<dist15[i]and dist13[i]<dist16[i]):
    
         
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
         
        soma13[0] = soma13[0] + x[i]
        soma13[1] = soma13[1] + y[i]
        
        count13 = count13 + 1
        count13_.append(count13)
        pontos13_.append([x[i],y[i]])
         
    elif(dist14[i]<dist1[i] and dist14[i]<dist2[i] and dist14[i]<dist3[i] and dist14[i]<dist4[i]and dist14[i]<dist5[i] and dist14[i]<dist6[i]and dist14[i]<dist7[i]and dist14[i]<dist8[i]and dist14[i]<dist9[i]and  dist14[i]<dist10[i] and dist14[i]<dist11[i]and dist14[i]<dist12[i]and dist14[i]<dist13[i]and dist14[i]<dist15[i]and dist14[i]<dist16[i]):
    
         
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
         
        soma14[0] = soma14[0] + x[i]
        soma14[1] = soma14[1] + y[i]
        
        count14 = count14 + 1
        count14_.append(count14)
        pontos14_.append([ x[i],y[i] ])
         
         
    elif(dist15[i]<dist1[i] and dist15[i]<dist2[i] and dist15[i]<dist3[i] and dist15[i]<dist4[i]and dist15[i]<dist5[i] and dist15[i]<dist6[i]and dist15[i]<dist7[i]and dist15[i]<dist8[i]and dist15[i]<dist9[i]and  dist15[i]<dist10[i] and dist15[i]<dist11[i]and dist15[i]<dist12[i]and dist15[i]<dist13[i]and dist15[i]<dist14[i]and dist15[i]<dist16[i]):
    
         
        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')
         
        soma15[0] = soma15[0] + x[i]
        soma15[1] = soma15[1] + y[i]
        
        count15 = count15+ 1
        count15_.append(count15)
        pontos15_.append([x[i],y[i]])
         
    elif(dist16[i]<dist1[i] and dist16[i]<dist2[i] and dist16[i]<dist3[i] and dist16[i]<dist4[i]and dist16[i]<dist5[i] and dist16[i]<dist6[i]and dist16[i]<dist7[i]and dist16[i]<dist8[i]and dist16[i]<dist9[i]and dist16[i]<dist10[i] and dist16[i]<dist11[i]and dist16[i]<dist12[i]and dist16[i]<dist13[i]and dist16[i]<dist14[i]and dist16[i]<dist15[i]):


        plt.plot(x[i],y[i],'yo')
        plt.plot(xc_1,yc_1,'ro')
        plt.plot(xc_2,yc_2,'ro')
        plt.plot(xc_3,yc_3,'ro')
        plt.plot(xc_4,yc_4,'ro')
        plt.plot(xc_5,yc_5,'ro')
        plt.plot(xc_6,yc_6,'ro')
        plt.plot(xc_7,yc_7,'ro')
        plt.plot(xc_8,yc_8,'ro')
        plt.plot(xc_9,yc_9,'ro')
        plt.plot(xc_10,yc_10,'ro')
        plt.plot(xc_11,yc_11,'ro')
        plt.plot(xc_12,yc_12,'ro')
        plt.plot(xc_13,yc_13,'ro')
        plt.plot(xc_14,yc_14,'ro')
        plt.plot(xc_15,yc_15,'ro')
        plt.plot(xc_16,yc_16,'ro')

        soma16[0] = soma16[0] + x[i]
        soma16[1] = soma16[1] + y[i]

        count16 = count16 + 1
        count16_.append(count16)

        pontos16_.append([x[i],y[i]])
                  
xc_1 = soma1[0]/(count1-1) # pois começamos em 1 a lista count para evitar problemas de 'index out of range'
yc_1 = soma1[1]/(count1-1)

xc_2 = soma2[0]/(count2-1)
yc_2 = soma2[1]/(count2-1)

xc_3 = soma3[0]/(count3-1)
yc_3 = soma3[1]/(count3-1)

xc_4 = soma4[0]/(count4-1)
yc_4 = soma4[1]/(count4-1)
         
xc_5 = soma5[0]/(count5-1)
yc_5 = soma5[1]/(count5-1)
         

xc_6 = soma6[0]/(count6-1)
yc_6 = soma6[1]/(count6-1)
         

xc_7 = soma7[0]/(count7-1)
yc_7 = soma7[1]/(count7-1)
         

xc_8 = soma8[0]/(count8-1)
yc_8 = soma8[1]/(count8-1)
         

xc_9 = soma9[0]/(count9-1)
yc_9= soma9[1]/(count9-1)
         

xc_10 = soma10[0]/(count10-1)
yc_10 = soma10[1]/(count10-1)
         

xc_11 = soma11[0]/(count11-1)
yc_11 = soma11[1]/(count11-1)
         

xc_12 = soma12[0]/(count12-1)
yc_12 = soma12[1]/(count12-1)
         

xc_13 = soma13[0]/(count13-1)
yc_13 = soma13[1]/(count13-1)
         

xc_14 = soma14[0]/(count14-1)
yc_14 = soma14[1]/(count14-1)

xc_15 = soma15[0]/(count15-1)
yc_15 = soma15[1]/(count15-1)

xc_16 = soma16[0]/(count16-1)
yc_16 = soma16[1]/(count16-1)



         

xc_1_.append(xc_1)


#------------------------------------------------------------------------------------------------------------------------------------

# %%
xc_1_
# Out:
# [0.40892113344371894,
#  0.33295021002457825,
#  0.3278685711927393,
#  0.3166272758274822,
#  0.31484971696302383,
#  0.31203785455789423,
#  0.3146131660175392,
#  0.3146131660175392,
#  0.3146131660175392]

# %%
ponto1 = [xc_1,yc_1]
ponto2 = [xc_2,yc_2]
ponto3 = [xc_3,yc_3]
ponto4 = [xc_4,yc_4]
ponto5 = [xc_5,yc_5]
ponto6 = [xc_6,yc_6]
ponto7 = [xc_7,yc_7]
ponto8 = [xc_8,yc_8]
ponto9 = [xc_9,yc_9]
ponto10 = [xc_10,yc_10]
ponto11= [xc_11,yc_11]
ponto12 = [xc_12,yc_12]
ponto13 = [xc_13,yc_13]
ponto14 = [xc_14,yc_14]
ponto15 = [xc_15,yc_15]
ponto16 = [xc_16,yc_16]


print(ponto1,ponto2,ponto3,ponto4,ponto5,ponto6,ponto7,ponto8,ponto9,ponto10,ponto11,ponto12,ponto13,ponto14,ponto15,ponto16)
# Out:
# [0.3146131660175392, 0.9237486721180778] [0.8628572591978984, 0.15685969086850673] [0.9207537910755101, 0.4266481536709171] [0.6016801485221249, 0.15411710679205523] [0.10944321680823933, 0.9016219915580431] [0.8815337676717889, 0.6715537338332308] [0.1134905595114341, 0.6104102738788353] [0.3021827364025564, 0.3640116441956078] [0.39021600880443996, 0.7800264564796296] [0.09924106797921081, 0.19315093656079604] [0.6584605444102261, 0.4033570728062167] [0.8554709493065655, 0.9117601529267007] [0.6582721966490197, 0.6660187522182782] [0.4625551326401861, 0.5110503185807473] [0.6188702514522955, 0.8819742413208798] [0.34462765191927913, 0.11453554230084952]

# %%
dist1_ = []
dist2_ = []
dist3_ = []
dist4_ = []
dist5_ = []
dist6_ = []
dist7_ = []
dist8_ = []
dist9_ = []
dist10_ = []
dist11_ = []
dist12_ = []
dist13_ = []
dist14_ = []
dist15_ = []
dist16_ = []


#---------------------- Calcular a distância de cada ponto para cada centróide-------------------

#----------Pontos1------------------
for i in range(len(pontos1_)):
    dist1_.append( ((ponto1[0] - pontos1_[i][0])**2 + (ponto1[1] - pontos1_[i][1])**2)**(0.5) )
    
#----------Pontos2------------------
for i in range(len(pontos2_)):
    dist2_.append( ((ponto2[0] - pontos2_[i][0])**2 + (ponto2[1] - pontos2_[i][1])**2)**(0.5) )
#----------Pontos3------------------
for i in range(len(pontos3_)):
    dist3_.append( ((ponto3[0] - pontos3_[i][0])**2 + (ponto3[1] - pontos3_[i][1])**2)**(0.5) )
#----------Pontos4------------------
for i in range(len(pontos4_)):
    dist4_.append( ((ponto4[0] - pontos4_[i][0])**2 + (ponto4[1] - pontos4_[i][1])**2)**(0.5) )
#----------Pontos5------------------
for i in range(len(pontos5_)):
    dist5_.append( ((ponto5[0] - pontos5_[i][0])**2 + (ponto5[1] - pontos5_[i][1])**2)**(0.5) )
#----------Pontos6------------------
for i in range(len(pontos6_)):
    dist6_.append( ((ponto6[0] - pontos6_[i][0])**2 + (ponto6[1] - pontos6_[i][1])**2)**(0.5) )
#----------Pontos7------------------
for i in range(len(pontos7_)):
    dist7_.append( ((ponto7[0] - pontos7_[i][0])**2 + (ponto7[1] - pontos7_[i][1])**2)**(0.5) )
#----------Pontos8------------------
for i in range(len(pontos8_)):
    dist8_.append( ((ponto8[0] - pontos8_[i][0])**2 + (ponto8[1] - pontos8_[i][1])**2)**(0.5) )
#----------Pontos9------------------
for i in range(len(pontos9_)):
    dist9_.append( ((ponto9[0] - pontos9_[i][0])**2 + (ponto9[1] - pontos9_[i][1])**2)**(0.5) )
#----------Pontos10------------------
for i in range(len(pontos10_)):
    dist10_.append( ((ponto10[0] - pontos10_[i][0])**2 + (ponto10[1] - pontos10_[i][1])**2)**(0.5) )
#----------Pontos11------------------
for i in range(len(pontos11_)):
    dist11_.append( ((ponto11[0] - pontos11_[i][0])**2 + (ponto11[1] - pontos11_[i][1])**2)**(0.5) )
#----------Pontos12------------------
for i in range(len(pontos12_)):
    dist12_.append( ((ponto12[0] - pontos12_[i][0])**2 + (ponto12[1] - pontos12_[i][1])**2)**(0.5) )
#----------Pontos13------------------
for i in range(len(pontos13_)):
    dist13_.append( ((ponto13[0] - pontos13_[i][0])**2 + (ponto13[1] - pontos13_[i][1])**2)**(0.5) )
#----------Pontos14------------------
for i in range(len(pontos14_)):
    dist14_.append( ((ponto14[0] - pontos14_[i][0])**2 + (ponto14[1] - pontos14_[i][1])**2)**(0.5) )
#----------Pontos15------------------
for i in range(len(pontos15_)):
    dist15_.append( ((ponto15[0] - pontos15_[i][0])**2 + (ponto15[1] - pontos15_[i][1])**2)**(0.5) )
#----------Pontos16------------------
for i in range(len(pontos16_)):
    dist16_.append( ((ponto16[0] - pontos16_[i][0])**2 + (ponto16[1] - pontos16_[i][1])**2)**(0.5) )

# %%
#-----Weights Distribution-----------------------

#----------------- Pontos1---------------------------------
w1 = []
sumdist1 = 0
k=4
for i in range(len(pontos1_)):
    sumdist1 = sumdist1 + dist1_[i]
    w1.append((sumdist1/dist1_[i])*(len(dist1_)/k))
    

#----------------- Pontos2---------------------------------
w2 = []
sumdist2 = 0
k=4
for i in range(len(pontos2_)):
    sumdist2 = sumdist2 + dist2_[i]
    w2.append((sumdist1/dist2_[i])*(len(dist2_)/k))
    

#----------------- Pontos3---------------------------------
w3 = []
sumdist3 = 0
k=4
for i in range(len(pontos3_)):
    sumdist3 = sumdist3 + dist3_[i]
    w3.append((sumdist3/dist3_[i])*(len(dist3_)/k))
    

#----------------- Pontos4---------------------------------
w4 = []
sumdist4 = 0
k=4
for i in range(len(pontos4_)):
    sumdist4 = sumdist4 + dist4_[i]
    w4.append((sumdist4/dist4_[i])*(len(dist4_)/k))
    

#----------------- Pontos5---------------------------------
w5 = []
sumdist5 = 0
k=4
for i in range(len(pontos5_)):
    sumdist5 = sumdist5 + dist5_[i]
    w5.append((sumdist5/dist5_[i])*(len(dist5_)/k))
    

#----------------- Pontos6---------------------------------
w6 = []
sumdist6 = 0
k=4
for i in range(len(pontos6_)):
    sumdist6 = sumdist6 + dist6_[i]
    w6.append((sumdist6/dist6_[i])*(len(dist6_)/k))
    

#----------------- Pontos7---------------------------------
w7 = []
sumdist7 = 0
k=4
for i in range(len(pontos7_)):
    sumdist7 = sumdist7 + dist7_[i]
    w7.append((sumdist7/dist7_[i])*(len(dist7_)/k))
    

#----------------- Pontos8---------------------------------
w8 = []
sumdist8 = 0
k=4
for i in range(len(pontos8_)):
    sumdist8 = sumdist8 + dist8_[i]
    w1.append((sumdist8/dist8_[i])*(len(dist8_)/k))
    

#----------------- Pontos1---------------------------------
w9 = []
sumdist9 = 0
k=4
for i in range(len(pontos9_)):
    sumdist9 = sumdist9 + dist9_[i]
    w9.append((sumdist9/dist9_[i])*(len(dist9_)/k))
    

#----------------- Pontos1---------------------------------
w10 = []
sumdist10 = 0
k=4
for i in range(len(pontos10_)):
    sumdist10 = sumdist10 + dist10_[i]
    w10.append((sumdist10/dist10_[i])*(len(dist10_)/k))
    

#----------------- Pontos11---------------------------------
w11 = []
sumdist11 = 0
k=4
for i in range(len(pontos11_)):
    sumdist11 = sumdist11 + dist11_[i]
    w11.append((sumdist11/dist11_[i])*(len(dist11_)/k))
    

#----------------- Pontos12---------------------------------
w12 = []
sumdist12 = 0
k=4
for i in range(len(pontos12_)):
    sumdist12 = sumdist12 + dist12_[i]
    w12.append((sumdist12/dist12_[i])*(len(dist12_)/k))
    

#----------------- Pontos13---------------------------------
w13 = []
sumdist13 = 0
k=4
for i in range(len(pontos13_)):
    sumdist13 = sumdist13 + dist13_[i]
    w13.append((sumdist13/dist13_[i])*(len(dist13_)/k))
    

#----------------- Pontos14---------------------------------
w14 = []
sumdist14 = 0
k=4
for i in range(len(pontos14_)):
    sumdist14 = sumdist14 + dist14_[i]
    w14.append((sumdist14/dist14_[i])*(len(dist14_)/k))
    

#----------------- Pontos15---------------------------------
w15 = []
sumdist15 = 0
k=4
for i in range(len(pontos15_)):
    sumdist15 = sumdist15 + dist15_[i]
    w15.append((sumdist15/dist15_[i])*(len(dist15_)/k))
    

#----------------- Pontos16---------------------------------
w16 = []
sumdist16 = 0
k=4
for i in range(len(pontos16_)):
    sumdist16 = sumdist16 + dist16_[i]
    w16.append((sumdist16/dist16_[i])*(len(dist16_)/k))

# %%
distrd1_ = []
distrd2_ = []
distrd3_ = []
distrd4_ = []
distrd5_ = []
distrd6_ = []
distrd7_ = []
distrd8_ = []
distrd9_ = []
distrd10_ = []
distrd11_ = []
distrd12_ = []
distrd13_ = []
distrd14_ = []
distrd15_ = []
distrd16_ = []

for i in range(len(dist1_)):
    distrd1_.append(round(dist1_[i],1))
for i in range(len(dist2_)):
    distrd2_.append(round(dist2_[i],1))
for i in range(len(dist3_)):
    distrd3_.append(round(dist3_[i],1))
for i in range(len(dist4_)):
    distrd4_.append(round(dist4_[i],1))
for i in range(len(dist5_)):
    distrd5_.append(round(dist5_[i],1))
for i in range(len(dist6_)):
    distrd6_.append(round(dist6_[i],1))
for i in range(len(dist7_)):
    distrd7_.append(round(dist7_[i],1))
for i in range(len(dist8_)):
    distrd8_.append(round(dist8_[i],1))
for i in range(len(dist9_)):
    distrd9_.append(round(dist9_[i],1))
for i in range(len(dist10_)):
    distrd10_.append(round(dist10_[i],1))
for i in range(len(dist11_)):
    distrd11_.append(round(dist11_[i],1))
for i in range(len(dist12_)):
    distrd12_.append(round(dist12_[i],1))
for i in range(len(dist13_)):
    distrd13_.append(round(dist13_[i],1))
for i in range(len(dist14_)):
    distrd14_.append(round(dist14_[i],1))
for i in range(len(dist15_)):
    distrd15_.append(round(dist15_[i],1))
for i in range(len(dist16_)):
    distrd16_.append(round(dist16_[i],1))
 

print(distrd1_.count(0.0),distrd1_.count(0.1),distrd1_.count(0.2),distrd1_.count(0.3))
print(distrd2_.count(0.0),distrd2_.count(0.1),distrd2_.count(0.2),distrd2_.count(0.3))
print(distrd3_.count(0.0),distrd3_.count(0.1),distrd3_.count(0.2),distrd3_.count(0.3))
print(distrd4_.count(0.0),distrd4_.count(0.1),distrd4_.count(0.2),distrd4_.count(0.3))
print(distrd5_.count(0.0),distrd5_.count(0.1),distrd5_.count(0.2),distrd5_.count(0.3))
print(distrd6_.count(0.0),distrd6_.count(0.1),distrd6_.count(0.2),distrd6_.count(0.3))
print(distrd7_.count(0.0),distrd7_.count(0.1),distrd7_.count(0.2),distrd7_.count(0.3))
print(distrd8_.count(0.0),distrd8_.count(0.1),distrd8_.count(0.2),distrd8_.count(0.3))
print(distrd9_.count(0.0),distrd9_.count(0.1),distrd9_.count(0.2),distrd9_.count(0.3))
print(distrd10_.count(0.0),distrd10_.count(0.1),distrd10_.count(0.2),distrd10_.count(0.3))
print(distrd11_.count(0.0),distrd11_.count(0.1),distrd11_.count(0.2),distrd11_.count(0.3))
print(distrd12_.count(0.0),distrd12_.count(0.1),distrd12_.count(0.2),distrd12_.count(0.3))
print(distrd13_.count(0.0),distrd13_.count(0.1),distrd13_.count(0.2),distrd13_.count(0.3))
print(distrd14_.count(0.0),distrd14_.count(0.1),distrd14_.count(0.2),distrd14_.count(0.3))
print(distrd15_.count(0.0),distrd15_.count(0.1),distrd15_.count(0.2),distrd15_.count(0.3))
print(distrd16_.count(0.0),distrd16_.count(0.1),distrd16_.count(0.2),distrd16_.count(0.3))
# Out:
# 7 13 1 0
# 5 28 3 0
# 5 21 0 0
# 7 25 3 0
# 7 18 0 0
# 8 26 1 0
# 5 23 10 0
# 2 31 3 0
# 1 28 2 0
# 3 27 11 0
# 5 28 1 0
# 6 24 0 0
# 3 29 1 0
# 2 22 1 0
# 6 20 0 0
# 9 17 2 0

# %%
coreset1 = []
coreset2 = []
coreset3 = []
coreset4 = []
coreset5 = []
coreset6 = []
coreset7 = []
coreset8 = []
coreset9 = []
coreset10 = []
coreset11 = []
coreset12 = []
coreset13 = []
coreset14 = []
coreset15= []
coreset16 = []

for i in range(len(pontos1_)):
    if(distrd1_[i] == 0.0):
        coreset1.append(pontos1_[i])
        
    
#    elif(distrd1_[i] == 0.1):
#        coreset1.append(pontos1_[i])
 

for i in range(len(pontos2_)):
    if(distrd2_[i] == 0.0):
        coreset2.append(pontos2_[i])
    
#    elif(distrd2_[i] == 0.1):
#        coreset2.append(pontos2_[i])
    
   

for i in range(len(pontos3_)):
    if(distrd3_[i] == 0.0):
        coreset3.append(pontos3_[i])
    
    #elif(distrd3_[i] == 0.1):
        #coreset3.append(pontos3_[i])
    
  
for i in range(len(pontos4_)):
    if(distrd4_[i] == 0.0):
        coreset4.append(pontos4_[i])
    
    #elif(distrd4_[i] == 0.1):
        #coreset4.append(pontos4_[i])

for i in range(len(pontos5_)):
    if(distrd5_[i] == 0.0):
        coreset5.append(pontos5_[i])
    
    #elif(distrd5_[i] == 0.1):
        #coreset5.append(pontos5_[i])


for i in range(len(pontos6_)):
    if(distrd6_[i] == 0.0):
        coreset6.append(pontos6_[i])
    
    #elif(distrd6_[i] == 0.1):
        #coreset6.append(pontos6_[i])

for i in range(len(pontos7_)):
    if(distrd7_[i] == 0.0):
        coreset7.append(pontos7_[i])
    
    #elif(distrd7_[i] == 0.1):
        #coreset7.append(pontos7_[i])
for i in range(len(pontos8_)):
    if(distrd8_[i] == 0.0):
        coreset8.append(pontos8_[i])
    
    #elif(distrd8_[i] == 0.1):
        #coreset8.append(pontos8_[i])
        
for i in range(len(pontos9_)):
    if(distrd9_[i] == 0.0):
        coreset9.append(pontos9_[i])
    
    #elif(distrd9_[i] == 0.1):
        #coreset9.append(pontos9_[i])
        
        
for i in range(len(pontos10_)):
    if(distrd10_[i] == 0.0):
        coreset10.append(pontos10_[i])
    
    #elif(distrd10_[i] == 0.1):
        #coreset10.append(pontos10_[i])

for i in range(len(pontos11_)):
    if(distrd11_[i] == 0.0):
        coreset11.append(pontos11_[i])
    
   # elif(distrd11_[i] == 0.1):
        #coreset11.append(pontos11_[i])
for i in range(len(pontos12_)):
    if(distrd12_[i] == 0.0):
        coreset12.append(pontos12_[i])
    
    #elif(distrd12_[i] == 0.1):
        #coreset12.append(pontos12_[i])
for i in range(len(pontos13_)):
    if(distrd13_[i] == 0.0):
        coreset13.append(pontos13_[i])
    
    #elif(distrd13_[i] == 0.1):
        #coreset13.append(pontos13_[i])
for i in range(len(pontos14_)):
    if(distrd14_[i] == 0.0):
        coreset14.append(pontos14_[i])
    
    #elif(distrd14_[i] == 0.1):
        #coreset14.append(pontos14_[i])
for i in range(len(pontos15_)):
    if(distrd15_[i] == 0.0):
        coreset15.append(pontos15_[i])
    
    #elif(distrd15_[i] == 0.1):
     #   coreset15.append(pontos15_[i])
for i in range(len(pontos16_)):
    if(distrd16_[i] == 0.0):
        coreset16.append(pontos16_[i])
    
    #elif(distrd16_[i] == 0.1):
     #   coreset16.append(pontos16_[i])

# %%
plt.figure(figsize=(20,20))
plotcor = []
for i in range(len(coreset1)):
    plotcor.append(coreset1[i])
for i in range(len(coreset2)):   
    plotcor.append(coreset2[i])
for i in range(len(coreset3)):    
    plotcor.append(coreset3[i])
for i in range(len(coreset4)):    
    plotcor.append(coreset4[i])
for i in range(len(coreset5)):    
    plotcor.append(coreset5[i])
for i in range(len(coreset6)):    
    plotcor.append(coreset6[i])
for i in range(len(coreset7)):    
    plotcor.append(coreset7[i])
for i in range(len(coreset8)):    
    plotcor.append(coreset8[i])
for i in range(len(coreset9)):    
    plotcor.append(coreset9[i])
for i in range(len(coreset10)):    
    plotcor.append(coreset10[i])
for i in range(len(coreset11)):    
    plotcor.append(coreset11[i])
for i in range(len(coreset12)):    
    plotcor.append(coreset12[i])
for i in range(len(coreset13)):    
    plotcor.append(coreset13[i])
for i in range(len(coreset14)):    
    plotcor.append(coreset14[i])
for i in range(len(coreset15)):    
    plotcor.append(coreset15[i])
for i in range(len(coreset16)):    
    plotcor.append(coreset16[i])

# %%
plt.figure(figsize=(20,20))
pontob_1 = []
pontok_2 = []
pontom_3 = []
pontog_4 = []
pontob_5 = []
pontok_6 = []
pontom_7 = []
pontog_8 = []
pontob_9 = []
pontok_10 = []
pontom_11 = []
pontog_12 = []
pontob_13 = []
pontok_14 = []
pontom_15 = []
pontog_16 = []

xc_1 =random.random()# gera uma coordenada x para o centroide 1 aleatória
yc_1=random.random() # gera uma coordenada y para o centróide 1 aleatória
pontob_1.append([xc_1,yc_1])
plt.plot(pontob_1[0][0],pontob_1[0][1],'bo') # plota o centróide (xc_1,yc_1) no gráfico



#-------------------------------------------------------------------
xc_2 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_2=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontok_2.append([xc_2,yc_2])
plt.plot(pontok_2[0][0],pontok_2[0][1],'ko') # plota o centróide (xc_2,yc_2) no gráfico

#-------------------------------------------------------------------

xc_3 =random.random()# gera uma coordenada x para o centroide 1 aleatória
yc_3=random.random() # gera uma coordenada y para o centróide 1 aleatória
pontom_3.append([xc_3,yc_3])
plt.plot(pontom_3[0][0],pontom_3[0][1],'mo') # plota o centróide (xc_1,yc_1) no gráfico



#-------------------------------------------------------------------
xc_4 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_4=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontog_4.append([xc_4,yc_4])
plt.plot(pontog_4[0][0],pontog_4[0][1],'go') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_5 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_5=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontob_5.append([xc_5,yc_5])
plt.plot(pontob_5[0][0],pontob_5[0][1],'bo') # plota o centróide (xc_2,yc_2) no gráfico

#-------------------------------------------------------------------
xc_6 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_6=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontok_6.append([xc_6,yc_6])
plt.plot(pontok_6[0][0],pontok_6[0][1],'ko') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_7 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_7=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontom_7.append([xc_7,yc_7])
plt.plot(pontom_7[0][0],pontom_7[0][1],'mo') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_8 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_8=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontog_8.append([xc_8,yc_8])
plt.plot(pontog_8[0][0],pontog_8[0][1],'go') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_9 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_9=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontob_9.append([xc_9,yc_9])
plt.plot(pontob_9[0][0],pontob_9[0][1],'bo') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_10 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_10=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontok_10.append([xc_10,yc_10])
plt.plot(pontok_10[0][0],pontok_10[0][1],'ko') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_11 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_11=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontom_11.append([xc_11,yc_11])
plt.plot(pontom_11[0][0],pontom_11[0][1],'mo') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_12 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_12=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontog_12.append([xc_12,yc_12])
plt.plot(pontog_12[0][0],pontog_12[0][1],'go') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_13 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_13=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontob_13.append([xc_13,yc_13])
plt.plot(pontob_13[0][0],pontob_13[0][1],'bo') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_14 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_14=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontok_14.append([xc_14,yc_14])
plt.plot(pontok_14[0][0],pontok_14[0][1],'ko') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_15 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_15=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontom_15.append([xc_15,yc_15])
plt.plot(pontom_15[0][0],pontom_15[0][1],'mo') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------
xc_16 =random.random()  # gera uma coordenada x para o centroide 2 aleatória
yc_16=random.random() # gera uma coordenada y para o centróide 2 aleatória
pontog_16.append([xc_16,yc_16])
plt.plot(pontog_16[0][0],pontog_16[0][1],'go') # plota o centróide (xc_2,yc_2) no gráfico
#-------------------------------------------------------------------




for i in range(len(plotcor)):
    plt.plot(plotcor[i][0],plotcor[i][1],'ro')

# %%
# Out:
# [[0.3794835092841665, 0.5993110356369022]]

# %%
dist1__ = []
dist2__ = []
dist3__ = []
dist4__ = []
dist5__ = []
dist6__ = []
dist7__ = []
dist8__ = []
dist9__ = []
dist10__ = []
dist11__ = []
dist12__ = []
dist13__ = []
dist14__ = []
dist15__ = []
dist16__ = []

dist1_rd = []
dist2_rd = []
dist3_rd = []
dist4_rd = []
dist5_rd = []
dist6_rd = []
dist7_rd = []
dist8_rd = []
dist9_rd = []
dist10_rd = []
dist11_rd = []
dist12_rd = []
dist13_rd = []
dist14_rd = []
dist15_rd = []
dist16_rd = []


for i in range(1):
    dist1__.append( ((pontob_1[0][0] - plotcor[i][0])**2 + (pontob_1[0][1] - plotcor[i][1])**2)**(0.5) )
    
for i in range(1):
    dist2__.append( ((pontok_2[0][0] - plotcor[i][0])**2 + (pontok_2[0][1] - plotcor[i][1])**2)**(0.5) )
    
for i in range(1):
    dist3__.append( ((pontom_3[0][0] - plotcor[i][0])**2 + (pontom_3[0][1] - plotcor[i][1])**2)**(0.5) )
    
for i in range(1):
    dist4__.append( ((pontog_4[0][0] - plotcor[i][0])**2 + (pontog_4[0][1] - plotcor[i][1])**2)**(0.5) )


for i in range(1):
    dist5__.append( ((pontob_5[0][0] - plotcor[i][0])**2 + (pontob_5[0][1] - plotcor[i][1])**2)**(0.5) )



for i in range(1):
    dist6__.append( ((pontok_6[0][0] - plotcor[i][0])**2 + (pontok_6[0][1] - plotcor[i][1])**2)**(0.5) )



for i in range(1):
    dist7__.append( ((pontom_7[0][0] - plotcor[i][0])**2 + (pontom_7[0][1] - plotcor[i][1])**2)**(0.5) )



for i in range(1):
    dist8__.append( ((pontog_8[0][0] - plotcor[i][0])**2 + (pontog_8[0][1] - plotcor[i][1])**2)**(0.5) )




for i in range(1):
    dist9__.append( ((pontob_9[0][0] - plotcor[i][0])**2 + (pontob_9[0][1] - plotcor[i][1])**2)**(0.5) )



for i in range(1):
    dist10__.append( ((pontok_10[0][0] - plotcor[i][0])**2 + (pontok_10[0][1] - plotcor[i][1])**2)**(0.5) )



for i in range(1):
    dist11__.append( ((pontom_11[0][0] - plotcor[i][0])**2 + (pontom_11[0][1] - plotcor[i][1])**2)**(0.5) )



for i in range(1):
    dist12__.append( ((pontog_12[0][0] - plotcor[i][0])**2 + (pontog_12[0][1] - plotcor[i][1])**2)**(0.5) )




for i in range(1):
    dist13__.append( ((pontob_13[0][0] - plotcor[i][0])**2 + (pontob_13[0][1] - plotcor[i][1])**2)**(0.5) )



for i in range(1):
    dist14__.append( ((pontok_14[0][0] - plotcor[i][0])**2 + (pontok_14[0][1] - plotcor[i][1])**2)**(0.5) )



for i in range(1):
    dist15__.append( ((pontom_15[0][0] - plotcor[i][0])**2 + (pontom_15[0][1] - plotcor[i][1])**2)**(0.5) )



for i in range(1):
    dist16__.append( ((pontog_16[0][0] - plotcor[i][0])**2 + (pontog_16[0][1] - plotcor[i][1])**2)**(0.5) )

# %%
dist1_rd = [] # Distância de cada ponto para o centróide 1
dist2_rd = [] # Distância de cada ponto para o centróide 2
dist3_rd = [] # Distância de cada ponto para o centróide 3
dist4_rd = [] # Distância de cada ponto para o centróide 4
dist5_rd = [] # Distância de cada ponto para o centróide 1
dist6_rd = [] # Distância de cada ponto para o centróide 2
dist7_rd = [] # Distância de cada ponto para o centróide 3
dist8_rd = [] # Distância de cada ponto para o centróide 4
dist9_rd = [] # Distância de cada ponto para o centróide 1
dist10_rd = [] # Distância de cada ponto para o centróide 2
dist11_rd = [] # Distância de cada ponto para o centróide 3
dist12_rd = [] # Distância de cada ponto para o centróide 4
dist13_rd = [] # Distância de cada ponto para o centróide 1
dist14_rd = [] # Distância de cada ponto para o centróide 2
dist15_rd = [] # Distância de cada ponto para o centróide 3
dist16_rd = [] # Distância de cada ponto para o centróide 4

cost_list = []

for i in range(len(dist1__)):
    dist1_rd.append(round(dist1__[i]*1000))
    cost_list.append(dist1_rd[0])

    
for i in range(len(dist2__)):
    dist2_rd.append(round(dist2__[i]*1000))
    cost_list.append(dist2_rd[0])

    
for i in range(len(dist3__)):
    dist3_rd.append(round(dist3__[i]*1000))
    cost_list.append(dist3_rd[0])


for i in range(len(dist4__)):
    dist4_rd.append(round(dist4__[i]*1000))
    cost_list.append(dist4_rd[0])


for i in range(len(dist5__)):
    dist5_rd.append(round(dist5__[i]*1000))
    cost_list.append(dist5_rd[0])


for i in range(len(dist6__)):
    dist6_rd.append(round(dist6__[i]*1000))
    cost_list.append(dist6_rd[0])

    
for i in range(len(dist7__)):
    dist7_rd.append(round(dist7__[i]*1000))
    cost_list.append(dist7_rd[0])

    
for i in range(len(dist8__)):
    dist8_rd.append(round(dist8__[i]*1000))
    cost_list.append(dist8_rd[0])

    
for i in range(len(dist9__)):
    dist9_rd.append(round(dist9__[i]*1000))
    cost_list.append(dist9_rd[0])

    
for i in range(len(dist10__)):
    dist10_rd.append(round(dist10__[i]*1000))
    cost_list.append(dist10_rd[0])

    
for i in range(len(dist11__)):
    dist11_rd.append(round(dist11__[i]*1000))
    cost_list.append(dist11_rd[0])

    
for i in range(len(dist12__)):
    dist12_rd.append(round(dist12__[i]*1000))
    cost_list.append(dist12_rd[0])

    
for i in range(len(dist13__)):
    dist13_rd.append(round(dist13__[i]*1000))
    cost_list.append(dist13_rd[0])

    
for i in range(len(dist14__)):
    dist14_rd.append(round(dist14__[i]*1000))
    cost_list.append(dist14_rd[0])

    
for i in range(len(dist15__)):
    dist15_rd.append(round(dist15__[i]*1000))
    cost_list.append(dist15_rd[0])

    
for i in range(len(dist16__)):
    dist16_rd.append(round(dist16__[i]*1000))
    cost_list.append(dist16_rd[0])

# %%
cost_list
# Out:
# [745, 284, 717, 322, 575, 64, 391, 816, 906, 339, 787, 743, 655, 829, 851, 390]

# %%
### Aqui entraria grover com as entradas acima, os pontos com maior peso possuem menor distância
